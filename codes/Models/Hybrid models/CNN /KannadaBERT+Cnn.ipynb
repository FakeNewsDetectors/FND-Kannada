# %% [markdown]
# ##Installation of Dependencies

# %%
# %matplotlib inline
# !pip install --quiet transformers
# !pip install -q pytorch_transformers
# !pip install -q tensorflow-text
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 61.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 29.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 40.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 80.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 103.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 11.6 MB/s eta 0:00:00
#   Building wheel for sacremoses (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 53.9 MB/s eta 0:00:00

# %% [markdown]
# ##Importing **Data Set**

# %%
TRAIN_DATASET_PATH = "/content/train.csv" # directory path where the training dataset is located
TEST_DATASET_PATH = "/content/test.csv" # directory path where the test dataset is located

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

train_df = pd.read_csv(TRAIN_DATASET_PATH)
test_df = pd.read_csv(TEST_DATASET_PATH)
test_df = test_df.dropna()
train_df = train_df.dropna()

# This hyperparameter can be set and has a preferred range between 0.1 and 0.2
validation_split = 0.1
train_df,val_df = train_test_split(train_df, test_size = validation_split, random_state = 100)
# When splitting data, an index column will be added. It is dropped using this command
train_df.reset_index(drop=True, inplace=True)
val_df.reset_index(drop=True, inplace=True)
test_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ##Importing the model

# %%
from transformers import AutoTokenizer, AutoModel

# Model checkpoint token: it is used to specify which model to download from pre trained hugging face models
model_tk="ai4bharat/indic-bert"
tokenizer = AutoTokenizer.from_pretrained(model_tk)
model = AutoModel.from_pretrained(model_tk)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/507 [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/5.65M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/135M [00:00<?, ?B/s]
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertModel: ['predictions.LayerNorm.weight', 'sop_classifier.classifier.weight', 'predictions.decoder.weight', 'predictions.dense.bias', 'predictions.dense.weight', 'predictions.LayerNorm.bias', 'predictions.bias', 'sop_classifier.classifier.bias', 'predictions.decoder.bias']
# - This IS expected if you are initializing AlbertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ##Tokenization of the Data

# %%
import numpy as np
import torch

# Set of functions used to build and tokenize the data with padding and converting it into torch tensors
def tokenize_text(df, max_seq):
    return [tokenizer.encode(text, add_special_tokens=True)[:max_seq] for text in df.news.values]


def pad_text(tokenized_text, max_seq):
    return np.array([el + [0] * (max_seq - len(el)) for el in tokenized_text])


def tokenize_and_pad_text(df, max_seq):
    tokenized_text = tokenize_text(df, max_seq)
    padded_text = pad_text(tokenized_text, max_seq)
    return torch.tensor(padded_text)


def targets_to_tensor(df, target_columns):
    return torch.tensor(df[target_columns].values, dtype=torch.float32)

# %%
max_seq = 60 # Hyperparameter
train_indices = tokenize_and_pad_text(train_df, max_seq)
val_indices = tokenize_and_pad_text(val_df, max_seq)
test_indices = tokenize_and_pad_text(test_df, max_seq)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
x = model.to(device)

# %% [markdown]
# ##Vectorization of the Data

# %%
with torch.no_grad():
    x_train = x(train_indices.to(device))[0]
    torch.cuda.empty_cache()  # Model's outputs are tuples
    x_val = x(val_indices.to(device))[0]
    torch.cuda.empty_cache()
    x_test = x(test_indices.to(device))[0]
    torch.cuda.empty_cache()

# %%
target_columns = ["label"]
y_train = targets_to_tensor(train_df, target_columns)
y_val = targets_to_tensor(val_df, target_columns)
y_test = targets_to_tensor(test_df, target_columns)

# %% [markdown]
# ##Model declaration

# %%
from tensorflow import random
random.set_seed(1) # To Create a stable model

# %%
import torch.nn as nn
import torch.nn.functional as F

class KimCNN(nn.Module):
    def __init__(self, embed_num, embed_dim, class_num, kernel_num, kernel_sizes, dropout, static):
        super(KimCNN, self).__init__()

        V = embed_num
        D = embed_dim
        C = class_num
        Co = kernel_num
        Ks = kernel_sizes

        self.static = static
        self.embed = nn.Embedding(V, D)
        self.convs1 = nn.ModuleList([nn.Conv2d(1, Co, (K, D)) for K in Ks])
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(len(Ks) * Co, C)
        self.sigmoid = nn.Sigmoid()



    def forward(self, x):
        if self.static:
            x = Variable(x)

        x = x.unsqueeze(1)  # (N, Ci, W, D)

        x = [F.relu(conv(x)).squeeze(3) for conv in self.convs1]  # [(N, Co, W), ...]*len(Ks)

        x = [F.max_pool1d(i, i.size(2)).squeeze(2) for i in x]  # [(N, Co), ...]*len(Ks)

        x = torch.cat(x, 1)
        x = self.dropout(x)  # (N, len(Ks)*Co)
        logit = self.fc1(x)  # (N, C)
        output = self.sigmoid(logit)
        return output

# %%
x_train.shape
# Out:
# torch.Size([2069, 60, 768])

# %%
embed_num = x_train.shape[1]
embed_dim = x_train.shape[2]
class_num = y_train.shape[1]
kernel_num = 10 # Kernel number tells you the number of kernels that are present per Convolution Network
kernel_sizes = [3,5,7,9] # Kernel or filter's Dimensions
dropout = 0 # Dropout fraction
static = True

# %%
# Declaration of model parameters
model = KimCNN(
    embed_num=embed_num,
    embed_dim=embed_dim,
    class_num=class_num,
    kernel_num=kernel_num,
    kernel_sizes=kernel_sizes,
    dropout=dropout,
    static=static,
)
model=model.to(device)

# %%
# Model Parameters
n_epochs = 250
batch_size = 16
lr = 0.00005
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
loss_fn = nn.BCELoss()

# %%
# Generates the Batches
def generate_batch_data(x, y, batch_size):
    i, batch = 0, 0
    for batch, i in enumerate(range(0, len(x) - batch_size, batch_size), 1):
        x_batch = x[i : i + batch_size]
        y_batch = y[i : i + batch_size]
        yield x_batch, y_batch, batch
    if i + batch_size < len(x):
        yield x[i + batch_size :], y[i + batch_size :], batch + 1
    if batch == 0:
        yield x, y, 1

# %% [markdown]
# ##Running The Model

# %%
import time
from torch.autograd import Variable

# Training the model with the train dataset
train_losses, val_losses = [], []
for epoch in range(n_epochs):
    start_time = time.time()
    train_loss = 0

    model.train(True)
    for x_batch, y_batch, batch in generate_batch_data(x_train, y_train, batch_size):
        y_pred = model(x_batch.to(device))
        optimizer.zero_grad()
        loss = loss_fn(y_pred.to(device), y_batch.to(device))
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_loss /= batch
    train_losses.append(train_loss)
    elapsed = time.time() - start_time

    # calculation of loss for the Validation Data
    model.eval()
    # deactivate autograd engine to reduce memory usage and speed up computations
    with torch.no_grad():
        val_loss, batch = 0, 1
        for x_batch, y_batch, batch in generate_batch_data(x_val, y_val, batch_size):
            y_pred = model(x_batch)
            loss = loss_fn(y_pred.to(device), y_batch.to(device))
            val_loss += loss.item()
        val_loss /= batch
        val_losses.append(val_loss)

    print(
        "Epoch %d Train loss: %.2f. Validation loss: %.2f. Elapsed time: %.2fs."
        % (epoch + 1, train_losses[-1], val_losses[-1], elapsed)
    )
# Out:
# Epoch 1 Train loss: 0.58. Validation loss: 0.59. Elapsed time: 5.06s.
# Epoch 2 Train loss: 0.50. Validation loss: 0.54. Elapsed time: 0.45s.
# Epoch 3 Train loss: 0.46. Validation loss: 0.51. Elapsed time: 0.39s.
# Epoch 4 Train loss: 0.42. Validation loss: 0.48. Elapsed time: 0.40s.
# Epoch 5 Train loss: 0.40. Validation loss: 0.46. Elapsed time: 0.38s.
# Epoch 6 Train loss: 0.38. Validation loss: 0.45. Elapsed time: 0.39s.
# Epoch 7 Train loss: 0.36. Validation loss: 0.44. Elapsed time: 0.38s.
# Epoch 8 Train loss: 0.34. Validation loss: 0.43. Elapsed time: 0.39s.
# Epoch 9 Train loss: 0.33. Validation loss: 0.42. Elapsed time: 0.38s.
# Epoch 10 Train loss: 0.31. Validation loss: 0.42. Elapsed time: 0.38s.
# Epoch 11 Train loss: 0.30. Validation loss: 0.41. Elapsed time: 0.39s.
# Epoch 12 Train loss: 0.29. Validation loss: 0.41. Elapsed time: 0.39s.
# Epoch 13 Train loss: 0.28. Validation loss: 0.40. Elapsed time: 0.38s.
# Epoch 14 Train loss: 0.27. Validation loss: 0.40. Elapsed time: 0.39s.
# Epoch 15 Train loss: 0.26. Validation loss: 0.39. Elapsed time: 0.39s.
# Epoch 16 Train loss: 0.25. Validation loss: 0.39. Elapsed time: 0.39s.
# Epoch 17 Train loss: 0.24. Validation loss: 0.39. Elapsed time: 0.38s.
# Epoch 18 Train loss: 0.23. Validation loss: 0.38. Elapsed time: 0.38s.
# Epoch 19 Train loss: 0.22. Validation loss: 0.38. Elapsed time: 0.39s.
# Epoch 20 Train loss: 0.22. Validation loss: 0.38. Elapsed time: 0.39s.
# Epoch 21 Train loss: 0.21. Validation loss: 0.38. Elapsed time: 0.39s.
# Epoch 22 Train loss: 0.20. Validation loss: 0.38. Elapsed time: 0.39s.
# Epoch 23 Train loss: 0.19. Validation loss: 0.37. Elapsed time: 0.40s.
# Epoch 24 Train loss: 0.19. Validation loss: 0.37. Elapsed time: 0.39s.
# Epoch 25 Train loss: 0.18. Validation loss: 0.37. Elapsed time: 0.38s.
# Epoch 26 Train loss: 0.18. Validation loss: 0.37. Elapsed time: 0.41s.
# Epoch 27 Train loss: 0.17. Validation loss: 0.37. Elapsed time: 0.46s.
# Epoch 28 Train loss: 0.16. Validation loss: 0.37. Elapsed time: 0.46s.
# Epoch 29 Train loss: 0.16. Validation loss: 0.37. Elapsed time: 0.44s.
# Epoch 30 Train loss: 0.15. Validation loss: 0.37. Elapsed time: 0.67s.
# Epoch 31 Train loss: 0.15. Validation loss: 0.37. Elapsed time: 0.74s.
# Epoch 32 Train loss: 0.14. Validation loss: 0.37. Elapsed time: 0.68s.
# Epoch 33 Train loss: 0.14. Validation loss: 0.36. Elapsed time: 0.42s.
# Epoch 34 Train loss: 0.13. Validation loss: 0.36. Elapsed time: 0.38s.
# Epoch 35 Train loss: 0.13. Validation loss: 0.36. Elapsed time: 0.38s.
# Epoch 36 Train loss: 0.12. Validation loss: 0.36. Elapsed time: 0.39s.
# Epoch 37 Train loss: 0.12. Validation loss: 0.36. Elapsed time: 0.39s.
# Epoch 38 Train loss: 0.12. Validation loss: 0.36. Elapsed time: 0.39s.
# Epoch 39 Train loss: 0.11. Validation loss: 0.36. Elapsed time: 0.38s.
# Epoch 40 Train loss: 0.11. Validation loss: 0.36. Elapsed time: 0.39s.
# Epoch 41 Train loss: 0.10. Validation loss: 0.36. Elapsed time: 0.39s.
# Epoch 42 Train loss: 0.10. Validation loss: 0.36. Elapsed time: 0.39s.
# Epoch 43 Train loss: 0.10. Validation loss: 0.36. Elapsed time: 0.39s.
# Epoch 44 Train loss: 0.09. Validation loss: 0.36. Elapsed time: 0.39s.
# Epoch 45 Train loss: 0.09. Validation loss: 0.36. Elapsed time: 0.38s.
# Epoch 46 Train loss: 0.09. Validation loss: 0.36. Elapsed time: 0.38s.
# Epoch 47 Train loss: 0.08. Validation loss: 0.36. Elapsed time: 0.39s.
# Epoch 48 Train loss: 0.08. Validation loss: 0.37. Elapsed time: 0.39s.
# Epoch 49 Train loss: 0.08. Validation loss: 0.37. Elapsed time: 0.39s.
# Epoch 50 Train loss: 0.08. Validation loss: 0.37. Elapsed time: 0.39s.
# Epoch 51 Train loss: 0.07. Validation loss: 0.37. Elapsed time: 0.39s.
# Epoch 52 Train loss: 0.07. Validation loss: 0.37. Elapsed time: 0.39s.
# Epoch 53 Train loss: 0.07. Validation loss: 0.37. Elapsed time: 0.39s.
# Epoch 54 Train loss: 0.06. Validation loss: 0.37. Elapsed time: 0.38s.
# Epoch 55 Train loss: 0.06. Validation loss: 0.37. Elapsed time: 0.39s.
# Epoch 56 Train loss: 0.06. Validation loss: 0.37. Elapsed time: 0.39s.
# Epoch 57 Train loss: 0.06. Validation loss: 0.37. Elapsed time: 0.42s.
# Epoch 58 Train loss: 0.06. Validation loss: 0.37. Elapsed time: 0.46s.
# Epoch 59 Train loss: 0.05. Validation loss: 0.37. Elapsed time: 0.45s.
# Epoch 60 Train loss: 0.05. Validation loss: 0.37. Elapsed time: 0.45s.
# Epoch 61 Train loss: 0.05. Validation loss: 0.38. Elapsed time: 0.46s.
# Epoch 62 Train loss: 0.05. Validation loss: 0.38. Elapsed time: 0.48s.
# Epoch 63 Train loss: 0.05. Validation loss: 0.38. Elapsed time: 0.50s.
# Epoch 64 Train loss: 0.04. Validation loss: 0.38. Elapsed time: 0.48s.
# Epoch 65 Train loss: 0.04. Validation loss: 0.38. Elapsed time: 0.40s.
# Epoch 66 Train loss: 0.04. Validation loss: 0.38. Elapsed time: 0.39s.
# Epoch 67 Train loss: 0.04. Validation loss: 0.38. Elapsed time: 0.39s.
# Epoch 68 Train loss: 0.04. Validation loss: 0.38. Elapsed time: 0.39s.
# Epoch 69 Train loss: 0.04. Validation loss: 0.38. Elapsed time: 0.39s.
# Epoch 70 Train loss: 0.03. Validation loss: 0.39. Elapsed time: 0.39s.
# Epoch 71 Train loss: 0.03. Validation loss: 0.39. Elapsed time: 0.39s.
# Epoch 72 Train loss: 0.03. Validation loss: 0.39. Elapsed time: 0.39s.
# Epoch 73 Train loss: 0.03. Validation loss: 0.39. Elapsed time: 0.39s.
# Epoch 74 Train loss: 0.03. Validation loss: 0.39. Elapsed time: 0.39s.
# Epoch 75 Train loss: 0.03. Validation loss: 0.39. Elapsed time: 0.39s.
# Epoch 76 Train loss: 0.03. Validation loss: 0.39. Elapsed time: 0.39s.
# Epoch 77 Train loss: 0.03. Validation loss: 0.40. Elapsed time: 0.39s.
# Epoch 78 Train loss: 0.02. Validation loss: 0.40. Elapsed time: 0.39s.
# Epoch 79 Train loss: 0.02. Validation loss: 0.40. Elapsed time: 0.40s.
# Epoch 80 Train loss: 0.02. Validation loss: 0.40. Elapsed time: 0.39s.
# Epoch 81 Train loss: 0.02. Validation loss: 0.40. Elapsed time: 0.40s.
# Epoch 82 Train loss: 0.02. Validation loss: 0.40. Elapsed time: 0.39s.
# Epoch 83 Train loss: 0.02. Validation loss: 0.41. Elapsed time: 0.40s.
# Epoch 84 Train loss: 0.02. Validation loss: 0.41. Elapsed time: 0.39s.
# Epoch 85 Train loss: 0.02. Validation loss: 0.41. Elapsed time: 0.39s.
# Epoch 86 Train loss: 0.02. Validation loss: 0.41. Elapsed time: 0.40s.
# Epoch 87 Train loss: 0.02. Validation loss: 0.41. Elapsed time: 0.41s.
# Epoch 88 Train loss: 0.02. Validation loss: 0.42. Elapsed time: 0.40s.
# Epoch 89 Train loss: 0.02. Validation loss: 0.42. Elapsed time: 0.46s.
# Epoch 90 Train loss: 0.02. Validation loss: 0.42. Elapsed time: 0.46s.
# Epoch 91 Train loss: 0.01. Validation loss: 0.42. Elapsed time: 0.47s.
# Epoch 92 Train loss: 0.01. Validation loss: 0.42. Elapsed time: 0.45s.
# Epoch 93 Train loss: 0.01. Validation loss: 0.43. Elapsed time: 0.48s.
# Epoch 94 Train loss: 0.01. Validation loss: 0.43. Elapsed time: 0.48s.
# Epoch 95 Train loss: 0.01. Validation loss: 0.43. Elapsed time: 0.48s.
# Epoch 96 Train loss: 0.01. Validation loss: 0.43. Elapsed time: 0.46s.
# Epoch 97 Train loss: 0.01. Validation loss: 0.43. Elapsed time: 0.40s.
# Epoch 98 Train loss: 0.01. Validation loss: 0.44. Elapsed time: 0.40s.
# Epoch 99 Train loss: 0.01. Validation loss: 0.44. Elapsed time: 0.39s.
# Epoch 100 Train loss: 0.01. Validation loss: 0.44. Elapsed time: 0.39s.
# Epoch 101 Train loss: 0.01. Validation loss: 0.44. Elapsed time: 0.39s.
# Epoch 102 Train loss: 0.01. Validation loss: 0.44. Elapsed time: 0.39s.
# Epoch 103 Train loss: 0.01. Validation loss: 0.45. Elapsed time: 0.39s.
# Epoch 104 Train loss: 0.01. Validation loss: 0.45. Elapsed time: 0.39s.
# Epoch 105 Train loss: 0.01. Validation loss: 0.45. Elapsed time: 0.38s.
# Epoch 106 Train loss: 0.01. Validation loss: 0.45. Elapsed time: 0.38s.
# Epoch 107 Train loss: 0.01. Validation loss: 0.45. Elapsed time: 0.39s.
# Epoch 108 Train loss: 0.01. Validation loss: 0.46. Elapsed time: 0.38s.
# Epoch 109 Train loss: 0.01. Validation loss: 0.46. Elapsed time: 0.39s.
# Epoch 110 Train loss: 0.01. Validation loss: 0.46. Elapsed time: 0.38s.
# Epoch 111 Train loss: 0.01. Validation loss: 0.46. Elapsed time: 0.38s.
# Epoch 112 Train loss: 0.01. Validation loss: 0.46. Elapsed time: 0.40s.
# Epoch 113 Train loss: 0.01. Validation loss: 0.46. Elapsed time: 0.38s.
# Epoch 114 Train loss: 0.01. Validation loss: 0.47. Elapsed time: 0.39s.
# Epoch 115 Train loss: 0.01. Validation loss: 0.47. Elapsed time: 0.39s.
# Epoch 116 Train loss: 0.01. Validation loss: 0.47. Elapsed time: 0.40s.
# Epoch 117 Train loss: 0.01. Validation loss: 0.47. Elapsed time: 0.40s.
# Epoch 118 Train loss: 0.01. Validation loss: 0.47. Elapsed time: 0.39s.
# Epoch 119 Train loss: 0.01. Validation loss: 0.47. Elapsed time: 0.39s.
# Epoch 120 Train loss: 0.01. Validation loss: 0.47. Elapsed time: 0.39s.
# Epoch 121 Train loss: 0.01. Validation loss: 0.47. Elapsed time: 0.45s.
# Epoch 122 Train loss: 0.01. Validation loss: 0.47. Elapsed time: 0.44s.
# Epoch 123 Train loss: 0.01. Validation loss: 0.48. Elapsed time: 0.45s.
# Epoch 124 Train loss: 0.01. Validation loss: 0.48. Elapsed time: 0.45s.
# Epoch 125 Train loss: 0.01. Validation loss: 0.48. Elapsed time: 0.47s.
# Epoch 126 Train loss: 0.01. Validation loss: 0.48. Elapsed time: 0.48s.
# Epoch 127 Train loss: 0.01. Validation loss: 0.48. Elapsed time: 0.47s.
# Epoch 128 Train loss: 0.01. Validation loss: 0.48. Elapsed time: 0.43s.
# Epoch 129 Train loss: 0.01. Validation loss: 0.48. Elapsed time: 0.39s.
# Epoch 130 Train loss: 0.01. Validation loss: 0.48. Elapsed time: 0.39s.
# Epoch 131 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.39s.
# Epoch 132 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.39s.
# Epoch 133 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.39s.
# Epoch 134 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.38s.
# Epoch 135 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.40s.
# Epoch 136 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.39s.
# Epoch 137 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.38s.
# Epoch 138 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.39s.
# Epoch 139 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.40s.
# Epoch 140 Train loss: 0.00. Validation loss: 0.49. Elapsed time: 0.41s.
# Epoch 141 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.39s.
# Epoch 142 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.40s.
# Epoch 143 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.39s.
# Epoch 144 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.39s.
# Epoch 145 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.39s.
# Epoch 146 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.39s.
# Epoch 147 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.40s.
# Epoch 148 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.39s.
# Epoch 149 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.38s.
# Epoch 150 Train loss: 0.00. Validation loss: 0.50. Elapsed time: 0.39s.
# Epoch 151 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.38s.
# Epoch 152 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.43s.
# Epoch 153 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.45s.
# Epoch 154 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.46s.
# Epoch 155 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.45s.
# Epoch 156 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.48s.
# Epoch 157 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.48s.
# Epoch 158 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.49s.
# Epoch 159 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.48s.
# Epoch 160 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.39s.
# Epoch 161 Train loss: 0.00. Validation loss: 0.51. Elapsed time: 0.39s.
# Epoch 162 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.39s.
# Epoch 163 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.40s.
# Epoch 164 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.39s.
# Epoch 165 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.39s.
# Epoch 166 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.39s.
# Epoch 167 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.38s.
# Epoch 168 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.39s.
# Epoch 169 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.39s.
# Epoch 170 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.39s.
# Epoch 171 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.39s.
# Epoch 172 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.38s.
# Epoch 173 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.38s.
# Epoch 174 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.38s.
# Epoch 175 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.38s.
# Epoch 176 Train loss: 0.00. Validation loss: 0.52. Elapsed time: 0.39s.
# Epoch 177 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.38s.
# Epoch 178 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.38s.
# Epoch 179 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.38s.
# Epoch 180 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.38s.
# Epoch 181 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.39s.
# Epoch 182 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.39s.
# Epoch 183 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.39s.
# Epoch 184 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.42s.
# Epoch 185 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.45s.
# Epoch 186 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.45s.
# Epoch 187 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.46s.
# Epoch 188 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.45s.
# Epoch 189 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.48s.
# Epoch 190 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.48s.
# Epoch 191 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.46s.
# Epoch 192 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.39s.
# Epoch 193 Train loss: 0.00. Validation loss: 0.53. Elapsed time: 0.40s.
# Epoch 194 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 195 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 196 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.40s.
# Epoch 197 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 198 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 199 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.40s.
# Epoch 200 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 201 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.40s.
# Epoch 202 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 203 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.41s.
# Epoch 204 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.40s.
# Epoch 205 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 206 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 207 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.38s.
# Epoch 208 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 209 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.41s.
# Epoch 210 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 211 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 212 Train loss: 0.00. Validation loss: 0.54. Elapsed time: 0.39s.
# Epoch 213 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.39s.
# Epoch 214 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.39s.
# Epoch 215 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.40s.
# Epoch 216 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.46s.
# Epoch 217 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.46s.
# Epoch 218 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.45s.
# Epoch 219 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.46s.
# Epoch 220 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.48s.
# Epoch 221 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.48s.
# Epoch 222 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.48s.
# Epoch 223 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.40s.
# Epoch 224 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.38s.
# Epoch 225 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.39s.
# Epoch 226 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.39s.
# Epoch 227 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.39s.
# Epoch 228 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.38s.
# Epoch 229 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.40s.
# Epoch 230 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.40s.
# Epoch 231 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.39s.
# Epoch 232 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.39s.
# Epoch 233 Train loss: 0.00. Validation loss: 0.55. Elapsed time: 0.39s.
# Epoch 234 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.39s.
# Epoch 235 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.38s.
# Epoch 236 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.38s.
# Epoch 237 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.39s.
# Epoch 238 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.38s.
# Epoch 239 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.38s.
# Epoch 240 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.38s.
# Epoch 241 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.39s.
# Epoch 242 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.40s.
# Epoch 243 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.39s.
# Epoch 244 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.39s.
# Epoch 245 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.39s.
# Epoch 246 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.39s.
# Epoch 247 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.44s.
# Epoch 248 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.45s.
# Epoch 249 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.45s.
# Epoch 250 Train loss: 0.00. Validation loss: 0.56. Elapsed time: 0.44s.

# %% [markdown]
# ##Plotting The loss graph

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Printing Loss graph
plt.plot(train_losses, label="Training loss")
plt.plot(val_losses, label="Validation loss")
plt.legend()
plt.title("Losses")
# Out:
# Text(0.5, 1.0, 'Losses')

# %% [markdown]
# ##Model Prediction

# %%
random.set_seed(1)

# %%
model.eval()
# Deactivate autograd engine to reduce memory usage and speed up computations
with torch.no_grad():
    y_preds = []
    batch = 0
    for x_batch, y_batch, batch in generate_batch_data(x_test, y_test, batch_size):
        y_pred = model(x_batch)
        y_preds.extend(y_pred.cpu().numpy().tolist())
    y_preds_np = np.array(y_preds)

# %%
# Preparing and Generating the Test labels
y_test_np = test_df[target_columns].values
y_test = list(map(lambda x: int(x) , y_test_np))
# Preparing the predicted variables
y_pred = y_preds_np.round()
y_pred = list(map(lambda x: int(x) , y_pred))

# %%
# classification report
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       200
#            1       0.89      0.90      0.90       300
#
#     accuracy                           0.87       500
#    macro avg       0.87      0.87      0.87       500
# weighted avg       0.87      0.87      0.87       500

# %%
# confusion matrix
from sklearn.metrics import  confusion_matrix

cm = confusion_matrix(y_test, y_pred)
cm_matrix = pd.DataFrame(data = cm)
sns.heatmap(cm_matrix, annot = True, fmt = 'd', cmap = 'YlGnBu')
# Out:
# <Axes: >
